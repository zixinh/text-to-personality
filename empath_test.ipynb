# %%
from empath import Empath
lexicon = Empath()

# %%
lexicon.analyze("i love all human beings", normalize=True)
# Out:
# {'achievement': 0.0,
#  'affection': 0.2,
#  'aggression': 0.0,
#  'air_travel': 0.0,
#  'alcohol': 0.0,
#  'ancient': 0.0,
#  'anger': 0.0,
#  'animal': 0.2,
#  'anonymity': 0.0,
#  'anticipation': 0.0,
#  'appearance': 0.0,
#  'art': 0.0,
#  'attractive': 0.0,
#  'banking': 0.0,
#  'beach': 0.0,
#  'beauty': 0.0,
#  'blue_collar_job': 0.0,
#  'body': 0.0,
#  'breaking': 0.0,
#  'business': 0.0,
#  'car': 0.0,
#  'celebration': 0.0,
#  'cheerfulness': 0.0,
#  'childish': 0.0,
#  'children': 0.0,
#  'cleaning': 0.0,
#  'clothing': 0.0,
#  'cold': 0.0,
#  'college': 0.0,
#  'communication': 0.0,
#  'competing': 0.0,
#  'computer': 0.0,
#  'confusion': 0.0,
#  'contentment': 0.0,
#  'cooking': 0.0,
#  'crime': 0.0,
#  'dance': 0.0,
#  'death': 0.0,
#  'deception': 0.0,
#  'disappointment': 0.0,
#  'disgust': 0.0,
#  'dispute': 0.0,
#  'divine': 0.0,
#  'domestic_work': 0.0,
#  'dominant_heirarchical': 0.0,
#  'dominant_personality': 0.0,
#  'driving': 0.0,
#  'eating': 0.0,
# ...

# %%
lexicon.analyze("i like dogs", normalize=True)
# Out:
# {'achievement': 0.0,
#  'affection': 0.0,
#  'aggression': 0.0,
#  'air_travel': 0.0,
#  'alcohol': 0.0,
#  'ancient': 0.0,
#  'anger': 0.0,
#  'animal': 0.0,
#  'anonymity': 0.0,
#  'anticipation': 0.0,
#  'appearance': 0.0,
#  'art': 0.0,
#  'attractive': 0.0,
#  'banking': 0.0,
#  'beach': 0.0,
#  'beauty': 0.0,
#  'blue_collar_job': 0.0,
#  'body': 0.0,
#  'breaking': 0.0,
#  'business': 0.0,
#  'car': 0.0,
#  'celebration': 0.0,
#  'cheerfulness': 0.0,
#  'childish': 0.0,
#  'children': 0.0,
#  'cleaning': 0.0,
#  'clothing': 0.0,
#  'cold': 0.0,
#  'college': 0.0,
#  'communication': 0.0,
#  'competing': 0.0,
#  'computer': 0.0,
#  'confusion': 0.0,
#  'contentment': 0.0,
#  'cooking': 0.0,
#  'crime': 0.0,
#  'dance': 0.0,
#  'death': 0.0,
#  'deception': 0.0,
#  'disappointment': 0.0,
#  'disgust': 0.0,
#  'dispute': 0.0,
#  'divine': 0.0,
#  'domestic_work': 0.0,
#  'dominant_heirarchical': 0.0,
#  'dominant_personality': 0.0,
#  'driving': 0.0,
#  'eating': 0.0,
# ...

# %%
lexicon.analyze("Prime Minister Justin Trudeau made an apology on behalf of the federal government for abuse and cultural losses at residential schools in Newfoundland and Labrador", normalize=True)
# Out:
# {'achievement': 0.0,
#  'affection': 0.0,
#  'aggression': 0.0,
#  'air_travel': 0.0,
#  'alcohol': 0.0,
#  'ancient': 0.0,
#  'anger': 0.0,
#  'animal': 0.0,
#  'anonymity': 0.0,
#  'anticipation': 0.0,
#  'appearance': 0.0,
#  'art': 0.0,
#  'attractive': 0.0,
#  'banking': 0.0,
#  'beach': 0.0,
#  'beauty': 0.0,
#  'blue_collar_job': 0.0,
#  'body': 0.0,
#  'breaking': 0.0,
#  'business': 0.0,
#  'car': 0.0,
#  'celebration': 0.0,
#  'cheerfulness': 0.0,
#  'childish': 0.0,
#  'children': 0.0,
#  'cleaning': 0.0,
#  'clothing': 0.0,
#  'cold': 0.0,
#  'college': 0.0,
#  'communication': 0.0,
#  'competing': 0.0,
#  'computer': 0.0,
#  'confusion': 0.0,
#  'contentment': 0.0,
#  'cooking': 0.0,
#  'crime': 0.0,
#  'dance': 0.0,
#  'death': 0.0,
#  'deception': 0.0,
#  'disappointment': 0.0,
#  'disgust': 0.0,
#  'dispute': 0.0,
#  'divine': 0.0,
#  'domestic_work': 0.0,
#  'dominant_heirarchical': 0.04,
#  'dominant_personality': 0.0,
#  'driving': 0.0,
#  'eating': 0.0,
# ...
